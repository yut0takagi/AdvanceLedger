# %%
from application import create_app, db

app = create_app()

# %%
with app.app_context():
    db.create_all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/share/virtualenvs/立て替え帳-U9nzk_In/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/.local/share/virtualenvs/立て替え帳-U9nzk_In/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~/.local/share/virtualenvs/立て替え帳-U9nzk_In/lib/python3.13/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
# ...
